# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Комментарий ревьюера</b>
#
#
# Привет, Виталий! Давай знакомиться! Меня зовут Дмитрий Махортов, и я буду проверять твой проект. Сразу предлагаю общение на «ты» 🙂, но если тебе это не комфортно, то дай знать, и мы перейдем на «вы».
#
#
# Моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе погрузиться в увлекательный мир работы с данными и вырасти в крепкого профи. Это отдаленная цель. А ближайшая - сделать твою работу еще лучше )).
#
#
# Все ключевые этапы в работе выполнены, и я вижу что с проектом ты справшяешься. Есть моменты, которые нужно доработать, но я уверен, у тебя все получится.
#
# Расскажу как обычно проходит проверка:
# Бывают моменты, которые требуют пристального внимания. Комментарии по ним выделены <span style='background-color:#F7B3A4'> красным цветом </span> и обозначены значком 🛑. После их доработки проект будет принят.  🙂
#
# <span style='background-color:#B7EBA7'> Зеленым цветом </span> и значком ✅ отмечены удачные и элегантные решения, на которые можно опираться в будущих проектах. Или советы «со звездочкой», которые помогут тебе в будущем.
#
# <span style='background-color:#F9EDA6'>Жёлтым цветом </span> и значком ⚠️ выделено то, что в следующий раз можно сделать по-другому. Ты можешь учесть эти комментарии при выполнении будущих заданий или доработать проект сейчас (однако это не обязательно).
#
# Давай работать над проектом в диалоге: **если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом**. Выбери для своих комментариев какой-то заметный цвет, так мне будет легче отследить изменения. Пожалуйста, **не перемещай, не изменяй и не удаляй мои комментарии**. Всё это поможет выполнить повторную проверку твоего проекта оперативнее.
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# Привет.<br>
# Приятно познакомиться и спасибо за советы.
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     <font size="3"><b>образец комментария студента</b></font>
#
# Можешь использовать этот комментарий. Просто удали этот текст и вместо него напиши свой 🙂
#
# </div>

# %% [markdown]
# # Прекод
#
# # Сборный проект-5
#
# Вам поручено разработать демонстрационную версию поиска изображений по запросу.
#
# Для демонстрационной версии нужно обучить модель, которая получит векторное представление изображения, векторное представление текста, а на выходе выдаст число от 0 до 1 — покажет, насколько текст и картинка подходят друг другу.
#
# ### Описание данных
#
# Данные доступны по [ссылке](https://code.s3.yandex.net/datasets/dsplus_integrated_project_4.zip).
#
# В файле `train_dataset.csv` находится информация, необходимая для обучения: имя файла изображения, идентификатор описания и текст описания. Для одной картинки может быть доступно до 5 описаний. Идентификатор описания имеет формат `<имя файла изображения>#<порядковый номер описания>`.
#
# В папке `train_images` содержатся изображения для тренировки модели.
#
# В файле `CrowdAnnotations.tsv` — данные по соответствию изображения и описания, полученные с помощью краудсорсинга. Номера колонок и соответствующий тип данных:
#
# 1. Имя файла изображения.
# 2. Идентификатор описания.
# 3. Доля людей, подтвердивших, что описание соответствует изображению.
# 4. Количество человек, подтвердивших, что описание соответствует изображению.
# 5. Количество человек, подтвердивших, что описание не соответствует изображению.
#
# В файле `ExpertAnnotations.tsv` содержатся данные по соответствию изображения и описания, полученные в результате опроса экспертов. Номера колонок и соответствующий тип данных:
#
# 1. Имя файла изображения.
# 2. Идентификатор описания.
#
# 3, 4, 5 — оценки трёх экспертов.
#
# Эксперты ставят оценки по шкале от 1 до 4, где 1 — изображение и запрос совершенно не соответствуют друг другу, 2 — запрос содержит элементы описания изображения, но в целом запрос тексту не соответствует, 3 — запрос и текст соответствуют с точностью до некоторых деталей, 4 — запрос и текст соответствуют полностью.
#
# В файле `test_queries.csv` находится информация, необходимая для тестирования: идентификатор запроса, текст запроса и релевантное изображение. Для одной картинки может быть доступно до 5 описаний. Идентификатор описания имеет формат `<имя файла изображения>#<порядковый номер описания>`.
#
# В папке `test_images` содержатся изображения для тестирования модели.

# %% [markdown]
# План работы:
#
# **Описание данных**
# - **train_dataset.csv**: Содержит информацию об изображениях для обучения, включая имя файла, идентификатор описания и текст описания. Одному изображению может соответствовать до 5 описаний.
# - **CrowdAnnotations.tsv**: Данные о соответствии изображения и описания, полученные с помощью краудсорсинга.
# - **ExpertAnnotations.tsv**: Данные о соответствии изображения и описания, собранные с помощью экспертов. Включает оценки трёх экспертов по шкале от 1 до 4.
# - **test_queries.csv**: Информация для тестирования с идентификаторами запросов, текстами запросов и релевантными изображениями.
# - **train_images** и **test_images**: Папки, содержащие изображения для обучения и тестирования соответственно.
#
# #### 1. Загрузка и предобработка данных
# 1. **Загрузить данные** и убедиться, что они корректно загружены.
# 2. **Проверить данные** на соответствие, целостность и отсутствие ошибок, таких как пропуски и дублирующиеся строки.
# 3. **Анализировать краудсорсинговые и экспертные данные**:
#     - Для **ExpertAnnotations.tsv**: агрегировать оценки экспертов, используя метод голосования большинства.
#     - Для **CrowdAnnotations.tsv**: обработать данные о доле и количестве подтверждений от исполнителей.
# 4. **Определение целевой переменной**: Привести оценку к значениям от 0 до 1 для вероятности соответствия.
# 5. **Агрегировать и нормализовать экспертные и краудсорсинговые оценки**, чтобы создать финальную целевую переменную.
# 6. **Объединить данные** в единый набор, подготовленный для следующего этапа анализа или построения модели.
#
# #### 2. Проверка данных на соответствие требованиям
# - **Удаление запрещённых изображений**: Исключить изображения, которые могут нарушать законодательство, с точки зрения использования изображений детей.
#
# #### 3. Векторизация изображений
# - **Использование сверточной сети (например, ResNet-18)**: Выделить главные компоненты изображений без полносвязных слоев, используя предобученную модель на датасете ImageNet для создания эмбеддингов изображений.
#
# #### 4. Векторизация текстов
# - **Тестирование разных методов**:
#   - **TF-IDF**
#   - **Word2Vec**
#   - **Трансформеры (например, BERT)** — для более сложных моделей, если они доступны.
#
# #### 5. Объединение векторов
# - **Подготовка данных для обучения**: Объединить векторы изображений и текстов вместе с целевой переменной для последующего обучения.
#
# #### 6. Обучение модели предсказания соответствия
# - **Разделение данных на тренировочную и тестовую выборки**: Использовать `GroupShuffleSplit` для разбиения, чтобы изображения были только в одной из выборок (тренировочной или тестовой).
# - **Выбор модели и метрики**:
#   - Определить подходящую модель для задачи.
#   - Выбрать или реализовать метрику качества предсказания (например, ROC-AUC или другая метрика для оценки соответствия).
#
# #### 7. Тестирование модели
# - **Получение эмбеддингов для тестовых изображений**: Использовать обученную модель для создания эмбеддингов для изображений из папки `test_images`.
# - **Выбор случайных запросов и проверка качества поиска**: Выбрать 10 случайных запросов из `test_queries.csv`, вывести наиболее релевантные изображения для каждого запроса и визуально оценить качество поиска.
#
# #### 8. Выводы
# - **Анализ результатов**: Оценить качество работы модели, выявить сильные и слабые стороны.
# - **Рекомендации**: Подумать о возможных улучшениях для будущих версий модели, включая возможные улучшения в архитектуре модели, методах векторизации, сборе дополнительных данных и так далее.

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
#
# Я вижу что для этого  раздела ты использовал маккдаун разметку (возможно сгенерировнную с помощью ChatGPT) и она вступает в конфликт с заголовками.
#
# Если твоя задача просто структурировнный текст, который будет комфортно читать, то лучше убрать лишние ###
#
#
# Сейчас даже простое чтение этого раздела вызывает дискомфорт.
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# Подправил
# </div>

# %% [markdown]
# ## 1. Исследовательский анализ данных
#
# Наш датасет содержит экспертные и краудсорсинговые оценки соответствия текста и изображения.
#
# В файле с экспертными мнениями для каждой пары изображение-текст имеются оценки от трёх специалистов. Для решения задачи вы должны эти оценки агрегировать — превратить в одну. Существует несколько способов агрегации оценок, самый простой — голосование большинства: за какую оценку проголосовала большая часть экспертов (в нашем случае 2 или 3), та оценка и ставится как итоговая. Поскольку число экспертов меньше числа классов, может случиться, что каждый эксперт поставит разные оценки, например: 1, 4, 2. В таком случае данную пару изображение-текст можно исключить из датасета.
#
# Вы можете воспользоваться другим методом агрегации оценок или придумать свой.
#
# В файле с краудсорсинговыми оценками информация расположена в таком порядке:
#
# 1. Доля исполнителей, подтвердивших, что текст **соответствует** картинке.
# 2. Количество исполнителей, подтвердивших, что текст **соответствует** картинке.
# 3. Количество исполнителей, подтвердивших, что текст **не соответствует** картинке.
#
# После анализа экспертных и краудсорсинговых оценок выберите либо одну из них, либо объедините их в одну по какому-то критерию: например, оценка эксперта принимается с коэффициентом 0.6, а крауда — с коэффициентом 0.4.
#
# Ваша модель должна возвращать на выходе вероятность соответствия изображения тексту, поэтому целевая переменная должна иметь значения от 0 до 1.

# %%
# !python -m pip install --upgrade pip --no-warn-script-location -q

# %%
pip install --upgrade torchvision -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade nltk --no-warn-script-location -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pandas matplotlib pyarrow numexpr -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install "numpy>=1.19.5,<1.27.0" "scipy>=1.7.0,<1.11.0" -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade seaborn -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
#
# Очень жестко... Я вижу что ты решил установить и обновить почти все  библиотеки.  Наверное с точки зрения совместимости это и корректно, но вот с точки зрения удобства не очень.
#
# Я не рискнул обновлять все библиотеки в своем окружении и создал новое. Полная установка заняла около 30 минут.
#
# А на дефолтных библитеках код просто не работал, т.к. я вижу что ты используешь какие-то очень хитрые настройки из новых библиотек.
#
# ----------------------------
#
# И как оказалось, чистое окружение тоже не панацея... например transformers, sklearn пришлось устанавливать дополнительно.
#
#
#
# -----------------------
#
# Также вызывает вопросы использование одновременно двух DL фреймворков ( tensorflow и torch).  Два фреймворка в одном окружении с использованием GPU- это мука. И такая же мука будет в продакшене. Поэтому как правило в одном проекте стараются использовать какой-то один фреймворк tf или torch.
#
#
# ----------------
#
# Вторая проблема - это "простыни" логов после установки. Стоит включить "тихий" режим, в этом случае логов после установки геренится меньше
#
#     !pip install -q swifter
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#   Тут была немного другая проблема, причём под утро и под конец проекта.<br>
#   К сожалению, ещё мало опыта работ с библиотеками.<br>
#   <br>
#   <span style="color:red; font-weight:bold;">TensorFlow</span> убрал из проекта
# </div>

# %%
import urllib.request
import zipfile
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import random
import re
import nltk
from collections import Counter
from functools import lru_cache
from nltk.corpus import stopwords
from tqdm import tqdm
from torch.utils.data import Dataset, DataLoader, TensorDataset
from torchvision import transforms
from torchvision.models import resnet18, ResNet18_Weights
from torchvision.io import read_image
from transformers import AutoTokenizer, AutoModel
from sklearn.model_selection import GroupShuffleSplit, train_test_split, RandomizedSearchCV
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.neural_network import MLPRegressor
from sklearn.decomposition import PCA
from pathlib import Path
from PIL import Image
from pylab import rcParams
from IPython.display import display, HTML

# Пути к данным
SERVER_PATH = 'https://code.s3.yandex.net/datasets/dsplus_integrated_project_4.zip'
HOME_PATH = './dsplus_integrated_project_4'
OUT_FILE = os.path.exists(HOME_PATH + '.zip')
img_folder_name = './to_upload/train_images'  # Путь к папке с изображениями
test_img_folder = './to_upload/test_images'  # Путь к папке с тестовыми изображениями

# Настройка глобального состояния генератора случайных чисел
rnd_state = 12345
np.random.seed(rnd_state)
random.seed(rnd_state)

# установим графическую тему для графиков и гистограмм
plt.style.use('seaborn-v0_8')

# настроим местоположение и размер шрифта для легенды и названий графиков и гистограмм
rcParams['legend.loc'] = 'upper left'
rcParams['legend.fontsize'] = 14
rcParams['axes.titlesize'] = 18 

#Расширяем границы
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Отлично, все нужные библиотеки импортированы в начале ноутбука.Это хорошая практика.</div>

# %%
# Функция для загрузки и распаковки архива
def download_and_extract():
    try:
        urllib.request.urlretrieve(SERVER_PATH, 'dsplus_integrated_project_4.zip')
        with zipfile.ZipFile('./dsplus_integrated_project_4.zip', 'r') as zip_ref:
            zip_ref.extractall(HOME_PATH)
        print("Архив успешно скачан и распакован.")
    except Exception as e:
        print(f"Ошибка при скачивании или распаковке: {e}")

# Функция для загрузки данных
def load_data():
    try:
        train_dataset_csv_path = os.path.join(HOME_PATH, 'to_upload', 'train_dataset.csv')
        crowd_annotations_tsv_path = os.path.join(HOME_PATH, 'to_upload', 'CrowdAnnotations.tsv')
        expert_annotations_tsv_path = os.path.join(HOME_PATH, 'to_upload', 'ExpertAnnotations.tsv')
        test_queries_csv_path = os.path.join(HOME_PATH, 'to_upload', 'test_queries.csv')
        test_images_csv_path = os.path.join(HOME_PATH, 'to_upload', 'test_images.csv')

        train_dataset = pd.read_csv(train_dataset_csv_path)
        print("train_dataset.csv загружен успешно.")
        
        crowd_annotations = pd.read_csv(crowd_annotations_tsv_path, sep='\t', header=None,
                                        names=['image', 'query_id', 'positive', 'n1', 'n2'])
        print("CrowdAnnotations.tsv загружен успешно.")
        
        expert_annotations = pd.read_csv(expert_annotations_tsv_path, sep='\t', header=None,
                                         names=['image', 'query_id', 'n1', 'n2', 'n3'])
        print("ExpertAnnotations.tsv загружен успешно.")
        
        test_queries = pd.read_csv(test_queries_csv_path, index_col=None, on_bad_lines='skip', delimiter='|')
        print("test_queries.csv загружен успешно.")
        
        test_images = pd.read_csv(test_images_csv_path)
        print("test_images.csv загружен успешно.")
        
        return train_dataset, crowd_annotations, expert_annotations, test_queries, test_images
    except FileNotFoundError as fnf_error:
        print(fnf_error)
        print("Попытка загрузить данные с сервера...")
        download_and_extract()
        # Повторная попытка загрузки данных после извлечения
        return load_data()

# Проверяем, если архив еще не скачан
if not OUT_FILE:
    download_and_extract()

# Загружаем данные
train_dataset, crowd_annotations, expert_annotations, test_queries, test_images = load_data()

# Проверка наличия файлов после распаковки
print()
print("Список файлов в HOME_PATH:", os.listdir(HOME_PATH))
print("Список файлов в папке to_upload:", os.listdir(os.path.join(HOME_PATH, 'to_upload')))
# Out:
# train_dataset.csv загружен успешно.
# CrowdAnnotations.tsv загружен успешно.
# ExpertAnnotations.tsv загружен успешно.
# test_queries.csv загружен успешно.
# test_images.csv загружен успешно.
#
# Список файлов в HOME_PATH: ['to_upload', '__MACOSX']
# Список файлов в папке to_upload: ['.DS_Store', 'CrowdAnnotations.tsv', 'ExpertAnnotations.tsv', 'test_images', 'test_images.csv', 'test_queries.csv', 'train_dataset.csv', 'train_images']

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Я вижу что ты застраховался "на все случаи", включая автоматическую загрузку датасета.
#
# Снимаю шляпу.
#
# </div>

# %% [markdown]
# Отлично, все файлы успешно загружены! Похоже, что теперь данные подготовлены и можно продолжить работу.
#
# В списке файлов видно, что в папке `to_upload` есть скрытые файлы, например, `.DS_Store`, который можно игнорировать. Также в папке присутствуют следующие файлы и папки:
#
# - `CrowdAnnotations.tsv`
# - `ExpertAnnotations.tsv`
# - `test_images.csv`
# - `test_queries.csv`
# - `train_dataset.csv`
# - `train_images`
# - `test_images`

# %%
# Список датафреймов
data_list = [train_dataset, crowd_annotations, expert_annotations, test_images, test_queries]

# Список названий
names_list = ["Train Dataset", "Crowd Annotations", "Expert Annotations", "Test Images", "Test Queries"]

# %%
# Функция для проверки данных
def check_data_list(data_list, names_list):
    """
    Функция для проверки списка датафреймов (аналог исходной функции).
    """
    for df, name in zip(data_list, names_list):
        print(f"\n{name} info:")
        display(df.info())
        print(f"\n{name} missing values:")
        display(df.isnull().sum())
        print(f"\n{name} sample:")
        display(df.head(10))

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
#
# Большой плюс функций - это возможность их переиспользовать. А сейчас функция получилась "одноразовая", т.к. без внесения изменений врядли мы сможем где-то еще её использовать.
#
# Думаю будет полезнее передавать в функцию единственный датафрейм, тогда у тебя появится универсальный инструмент.
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# Подправил
# </div>

# %%
check_data_list(data_list, names_list)
# Out:
# Train Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5822 entries, 0 to 5821
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   image       5822 non-null   object
#  1   query_id    5822 non-null   object
#  2   query_text  5822 non-null   object
# dtypes: object(3)
# memory usage: 136.6+ KB
# None
# Train Dataset missing values:
# image         0
# query_id      0
# query_text    0
# dtype: int64
# Train Dataset sample:
#                        image                     query_id  \
# 0  1056338697_4f7d7ce270.jpg  2549968784_39bfbe44f9.jpg#2
# 1  1262583859_653f1469a9.jpg  2549968784_39bfbe44f9.jpg#2
# 2  2447284966_d6bbdb4b6e.jpg  2549968784_39bfbe44f9.jpg#2
# 3  2549968784_39bfbe44f9.jpg  2549968784_39bfbe44f9.jpg#2
# 4  2621415349_ef1a7e73be.jpg  2549968784_39bfbe44f9.jpg#2
# 5  3030566410_393c36a6c5.jpg  2549968784_39bfbe44f9.jpg#2
# ...

# %% [markdown]
# **Дополненные выводы по набору данных:**
#
# 1. **Train Dataset**:
#    - Размер набора данных остается 5822 строки и 3 столбца: `image`, `query_id` и `query_text`.
#    - Все данные заполнены, пропусков нет.
#    - Столбцы содержат текстовые данные, связанные с изображениями, уникальными идентификаторами запросов и текстовыми описаниями запросов.
# <BR></BR>
# 2. **Crowd Annotations**:
#    - Размер набора данных — 47830 строк и 5 столбцов: `image`, `query_id`, `positive`, `n1`, `n2`.
#    - Все данные заполнены, пропусков нет.
#    - Столбец `positive` содержит значения от 0 до 1(Доля людей, подтвердивших, что описание соответствует изображению.), столбцы; `n1`(Количество человек, подтвердивших, что описание соответствует изображению.) и `n2`(Количество человек, подтвердивших, что описание не соответствует изображению.) — целочисленные значения, относящиеся к количеству голосов или уверенности аннотации.
# <BR></BR>
# 3. **Expert Annotations**:
#    - Набор данных содержит 5822 строки и 5 столбцов: `image`, `query_id`, `n1`, `n2`, `n3`.
#    - Все данные заполнены, пропусков нет.
#    - Столбцы `n1`, `n2`, `n3` содержат целочисленные значения, которые отражают оценки трёх экспертов.
# <BR></BR>
# 4. **Test Images**:
#    - Этот набор данных состоит из 100 изображений (столбец `image`), для которых нужно выполнить тестирование.
#    - Пропусков в данных нет.
# <BR></BR>
# 5. **Test Queries**:
#    - Набор данных состоит из 500 строк и 4 столбцов: `Unnamed: 0`, `query_id`, `query_text`, `image`.
#    - Все данные заполнены, пропусков нет.
# <BR></BR>
#
# **Общие выводы**:
# - Все данные, включая тестовые наборы, заполнены без пропусков, что значительно облегчает подготовку данных для анализа и обучения.
# - В `Crowd Annotations` имеется значительно больше записей, что указывает на большую вариативность в оценках от множества участников.
# - Набор `Expert Annotations` содержит больше информации о каждом запросе и изображении, предоставляя более точные аннотации.
# - Столбец `query_id` присутствует во всех наборах данных и служит хорошей связующей переменной для объединения информации из разных источников (например, для сопоставления запросов с изображениями и аннотациями).
# - В **Test Images** и **Test Queries** данные о тестовых изображениях и запросах достаточно компактны, что позволяет легко их обрабатывать для тестирования модели.
# - Столбец `Unnamed: 0` нужно будет удалить, так как это явный индекс оставшийся по ошибке.

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# ОК, данные загружены, есть первичное знакомство и промежуточные выводы </div>

# %%
# Удаляем столбец 'Unnamed: 0' из DataFrame
test_queries = test_queries.drop(columns=['Unnamed: 0'])

# Проверяем, что столбец удален
print(test_queries.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   query_id    500 non-null    object
#  1   query_text  500 non-null    object
#  2   image       500 non-null    object
# dtypes: object(3)
# memory usage: 11.8+ KB
# None

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#  👍 </div>

# %%
# Путь к папкам с изображениями
train_images_path = Path(HOME_PATH, 'to_upload', 'train_images')
test_images_path = Path(HOME_PATH, 'to_upload', 'test_images')

# Выборка примеров изображений для тренировки и тестирования
samples_train = list(train_dataset['image'].sample(13))  # 13 тренировочных изображений
samples_test = list(test_queries['image'].sample(12))    # 12 тестовых изображений

# Настройка сетки 5x5 для отображения
fig = plt.figure(figsize=(12, 12))
for i in range(25):
    fig.add_subplot(5, 5, i + 1)
    
    # Загрузка и отображение изображения
    if i < len(samples_train):
        image = Image.open(train_images_path / samples_train[i])
        title = f'Train {i + 1}'
    else:
        image = Image.open(test_images_path / samples_test[i - len(samples_train)])
        title = f'Test {i - len(samples_train) + 1}'
    
    # Показ изображения и добавление подписи
    plt.imshow(image)
    plt.title(title, fontsize=10)
    plt.xticks([])
    plt.yticks([])

# Один раз вызов tight_layout для подгона расположения
plt.tight_layout(pad=3.0)

plt.show()

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#  👍 </div>

# %% [markdown]
# **Анализ распределения query_id и image**

# %% [markdown]
# По данным изображениям можно сделать следующий вывод:
#
# В представленном наборе изображений наблюдается значительное разнообразие сцен и объектов, что подтверждает его пригодность для анализа широкого спектра поведенческих и визуальных паттернов.
# Изображения можно условно разделить на несколько категорий: сцены с людьми в повседневной обстановке (демонстрации, шопинг, отдых на пляже), детские игры и спортивные мероприятия (футбол, баскетбол, катание на велосипеде), животные в движении (собаки, играющие или бегущие), а также активный отдых на природе (плавание, катание на лыжах). Данное разнообразие позволяет предположить, что набор изображений охватывает различные аспекты социальной и индивидуальной активности, что делает его полезным для исследования моделей поведения и классификации визуальных объектов.

# %%
def check_relationships(df, df_name):
    """
    Проверяет связь между query_id, image и query_text в наборе данных.

    Параметры:
    - df: DataFrame, набор данных для анализа.
    - df_name: str, имя набора данных (для вывода информации).
    """
    print(f"Анализ набора данных: {df_name}")
    print("=" * 50)

    # Проверка наличия столбцов
    required_columns = ['query_id', 'image', 'query_text']
    missing_columns = [col for col in required_columns if col not in df.columns]
    if missing_columns:
        print(f"Отсутствуют столбцы: {missing_columns}")
        return

    # Уникальные значения
    unique_query_id = df['query_id'].nunique()
    unique_image = df['image'].nunique()
    unique_query_text = df['query_text'].nunique()

    print(f"Уникальные query_id: {unique_query_id}")
    print(f"Уникальные image: {unique_image}")
    print(f"Уникальные query_text: {unique_query_text}")

    # Связь между query_id и image (с сортировкой)
    query_id_image = df.groupby('query_id')['image'].nunique().reset_index(name='unique_images')
    query_id_image = query_id_image.sort_values(by='unique_images', ascending=False)  # Сортировка
    print("\nСвязь между query_id и image (отсортировано по убыванию):")
    display(query_id_image.head())

    # Связь между query_id и query_text (с сортировкой)
    query_id_query_text = df.groupby('query_id')['query_text'].nunique().reset_index(name='unique_query_texts')
    query_id_query_text = query_id_query_text.sort_values(by='unique_query_texts', ascending=False)  # Сортировка
    print("\nСвязь между query_id и query_text (отсортировано по убыванию):")
    display(query_id_query_text.head())

    # Связь между image и query_text (с сортировкой)
    image_query_text = df.groupby('image')['query_text'].nunique().reset_index(name='unique_query_texts')
    image_query_text = image_query_text.sort_values(by='unique_query_texts', ascending=False)  # Сортировка
    print("\nСвязь между image и query_text (отсортировано по убыванию):")
    display(image_query_text.head())

    # Примеры строк с дубликатами query_id
    duplicate_query_id = df[df.duplicated('query_id', keep=False)]
    if not duplicate_query_id.empty:
        print("\nПримеры строк с дубликатами query_id:")
        display(duplicate_query_id.head())

    # Примеры строк с дубликатами image
    duplicate_image = df[df.duplicated('image', keep=False)]
    if not duplicate_image.empty:
        print("\nПримеры строк с дубликатами image:")
        display(duplicate_image.head())

    print("\n" + "=" * 50 + "\n")

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
#
# Не советую использовать функцию `print()` для вывода датафреймов, получается не очень красиво. В большинстве случаев можно вообще обойтись без команды, достаточно обратиться к таблице в последней строке ячейки. Или использовать функцию `display()`
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# Подправил
# </div>

# %%
check_relationships(train_dataset, "Train Dataset")
# Out:
# Анализ набора данных: Train Dataset
# ...
# Уникальные query_id: 977
# Уникальные image: 1000
# Уникальные query_text: 977
#
# Связь между query_id и image (отсортировано по убыванию):
#                         query_id  unique_images
# 301  2600867924_cd502fc911.jpg#2             34
# 74   1554713437_61b64527dd.jpg#2             27
# 270  2522297487_57edf117f7.jpg#2             25
# 71   1536774449_e16b1b6382.jpg#2             25
# 600  3254817653_632e840423.jpg#2             22
# Связь между query_id и query_text (отсортировано по убыванию):
#                         query_id  unique_query_texts
# 0    1056338697_4f7d7ce270.jpg#2                   1
# 642  3347798761_5c5260b000.jpg#2                   1
# 644  3350786891_6d39b234e9.jpg#2                   1
# 645  3353036763_4cbeba03b2.jpg#2                   1
# 646  3354330935_de75be9d2f.jpg#2                   1
# Связь между image и query_text (отсортировано по убыванию):
#                          image  unique_query_texts
# ...

# %%
check_relationships(test_queries, "Test Queries")
# Out:
# Анализ набора данных: Test Queries
# ...
# Уникальные query_id: 500
# Уникальные image: 100
# Уникальные query_text: 500
#
# Связь между query_id и image (отсортировано по убыванию):
#                         query_id  unique_images
# 0    1177994172_10d143cb8d.jpg#0              1
# 329  3421547427_53411b6278.jpg#4              1
# 342  3455405300_aa3069ecaa.jpg#2              1
# 341  3455405300_aa3069ecaa.jpg#1              1
# 340  3455405300_aa3069ecaa.jpg#0              1
# Связь между query_id и query_text (отсортировано по убыванию):
#                         query_id  unique_query_texts
# 0    1177994172_10d143cb8d.jpg#0                   1
# 329  3421547427_53411b6278.jpg#4                   1
# 342  3455405300_aa3069ecaa.jpg#2                   1
# 341  3455405300_aa3069ecaa.jpg#1                   1
# 340  3455405300_aa3069ecaa.jpg#0                   1
# Связь между image и query_text (отсортировано по убыванию):
#                         image  unique_query_texts
# ...

# %%
# Создаём сетку 2x2
fig, axes = plt.subplots(2, 2, figsize=(16, 12))

# Увеличиваем расстояние между графиками
plt.subplots_adjust(wspace=0.5, hspace=0.6)  # Увеличены расстояния

# 1. Распределение query_id по количеству связанных image
query_id_image_counts = train_dataset.groupby('query_id')['image'].nunique().reset_index(name='image_count')
sns.histplot(query_id_image_counts['image_count'], bins=20, kde=True, ax=axes[0, 0])
axes[0, 0].set_title('Распределение query_id по количеству image')
axes[0, 0].set_xlabel('Количество image')
axes[0, 0].set_ylabel('Частота')

# 2. Распределение image по количеству связанных query_id
image_query_id_counts = train_dataset.groupby('image')['query_id'].nunique().reset_index(name='query_id_count')
sns.histplot(image_query_id_counts['query_id_count'], bins=20, kde=True, ax=axes[0, 1])
axes[0, 1].set_title('Распределение image по количеству query_id')
axes[0, 1].set_xlabel('Количество query_id')
axes[0, 1].set_ylabel('Частота')

# 3. Топ-10 query_id по количеству связанных image
top_query_id = query_id_image_counts.sort_values(by='image_count', ascending=False).head(10)
sns.barplot(x='image_count', y='query_id', data=top_query_id, hue='query_id', palette='viridis', legend=False, ax=axes[1, 0])
axes[1, 0].set_title('Топ-10 query_id по количеству image')
axes[1, 0].set_xlabel('Количество image')
axes[1, 0].set_ylabel('query_id')

# 4. Топ-10 image по количеству связанных query_id
top_image = image_query_id_counts.sort_values(by='query_id_count', ascending=False).head(10)
sns.barplot(x='query_id_count', y='image', data=top_image, hue='image', palette='viridis', legend=False, ax=axes[1, 1])
axes[1, 1].set_title('Топ-10 image по количеству query_id')
axes[1, 1].set_xlabel('Количество query_id')
axes[1, 1].set_ylabel('image')

# Отображаем графики
plt.show()

# %%
# Проверяем дубликаты query_id с разными query_text
duplicates = train_dataset.groupby('query_id')['query_text'].nunique()
duplicates = duplicates[duplicates > 1]

if not duplicates.empty:
    print("Обнаружены query_id с разными query_text:")
    print(duplicates)
else:
    print("Дубликатов query_id с разными query_text не обнаружено.")
# Out:
# Дубликатов query_id с разными query_text не обнаружено.

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#
# Интересные наблюдения.
#
# Думаю что датасет собирался примерно следующим образом: авторы взяли 1000 изображений из датасета flickr8 (или flickr32) и 1000 описанний к ним.
#
# А затем было взято какое-то количество пар из пересечения (т.е. бралось рандомное изображение и рандомное описание и формировлась пара).
#
# И уже эти пары оценивали краудсорсеры и эксперты. Понятно, что из-за рандома какие-то изображения/описания попали в эти пары чаще, какие-то реже.
#
# </div>

# %% [markdown]
# **Выводы:**
#
# 1. **`query_id` и `query_text`**:
#    - Каждый `query_id` соответствует уникальному `query_text`.
#    - Один `query_id` может быть связан с несколькими изображениями (`image`), причём большинство запросов охватывают 1–5 изображений, а некоторые — до 35, что указывает на их универсальность.<br>
#
#
# 2. **`image` и `query_text`**:
#    - Одно изображение (`image`) может быть связано с несколькими `query_text`, то есть описано несколькими запросами.
#    - Большинство изображений связано с 2–5 запросами, но некоторые используются в до 10 запросах, что говорит об их широком применении.<br>
#
#
# 3. **Дубликаты и связи**:
#    - Дубликаты `query_id` и `image` подтверждают, что связь между ними не является однозначной.
#    - Один `query_id` может быть связан с несколькими `image`, и одно `image` может быть связано с несколькими `query_id`.<br>
#
# 4. **Топ-10**:
#    - Запросы и изображения из топ-10 имеют наибольшее количество связей, что может указывать на их популярность или универсальность.

# %% [markdown]
# **Анализ распределения оценок краудсорсинга**

# %%
# Копируем данные для анализа
crowd_analytics = crowd_annotations.copy()

# Преобразуем столбец 'positive' в проценты и приводим к целому типу
crowd_analytics['positive'] = (crowd_analytics['positive'] * 100).astype(int)

# Подсчитываем количество каждой доли с помощью value_counts
crowd_counts = crowd_analytics['positive'].value_counts().sort_index()

# Вывод информации текстом
print("Анализ распределения оценок краудсорсинга:")
for percentage, count in crowd_counts.items():
    print(f"{percentage}%: {count} ответов")

print(f"\nОбщее количество ответов: {crowd_counts.sum()}")

# Строим график
plt.figure(figsize=(14, 8))
sns.barplot(x=crowd_counts.index, y=crowd_counts.values)
plt.xticks(rotation=45, size=12)  # Поворот меток для лучшей читаемости
plt.xlabel('Процент соответствия описания изображению (%)')
plt.ylabel('Количество')
plt.title('График распределения оценок краудсорсинга')
plt.show()
# Out:
# Анализ распределения оценок краудсорсинга:
# 0%: 41970 ответов
# 16%: 3 ответов
# 20%: 22 ответов
# 25%: 96 ответов
# 33%: 3000 ответов
# 40%: 8 ответов
# 50%: 27 ответов
# 60%: 8 ответов
# 66%: 1360 ответов
# 75%: 9 ответов
# 80%: 4 ответов
# 100%: 1323 ответов
#
# Общее количество ответов: 47830

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#  👍 </div>

# %% [markdown]
# **Вывод**: На графике видно, что распределение оценок имеет ярко выраженный пик на 0%, что подтверждает преобладание низких оценок. Это также подчеркивает проблему с соответствием изображений их описанию.

# %%
# Тепловая карта корреляции
plt.figure(figsize=(8, 6))
sns.heatmap(expert_annotations[['n1', 'n2', 'n3']].corr(), annot=True, cmap='coolwarm')
plt.title('Корреляция между оценками экспертов')
plt.show()

# %% [markdown]
# **Анализ корреляционной матрицы:**
#
# 1. **Высокая корреляция между оценками экспертов:**
#    - **n1 и n2**: коэффициент **0.89**.
#    - **n2 и n3**: коэффициент **0.87**.
#    - **n1 и n3**: коэффициент **0.80**.
#
#    Эти значения показывают сильную связь между оценками экспертов, что подтверждает их согласованность.</BR>
#    Однако корреляция между **n1 и n3** несколько ниже, чем между остальными парами.<BR></BR>
#
# 2. **Общий вывод о согласованности:**
#    - Все значения корреляции достаточно высоки, что указывает на схожие подходы экспертов при выставлении оценок.
#    - Между экспертами **n1** и **n3** корреляция ниже, что может означать некоторое различие в их критериях оценки.</BR>
#
# **Выбор метода агрегации:**
#
#    - Учитывая высокую корреляцию, можно использовать метод среднего арифметического вместо голосования большинства.
#    - Такой подход позволит сохранить все записи, даже если оценки экспертов различаются.

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# ОК, хотя вывод, что учитывая корреляцию можно использовать среднее-арифметическое мне кажется "натяжкой".  </div>

# %%
# Для агрегации используем среднее арифметическое
expert_annotations['aggregated_score'] = expert_annotations[['n1', 'n2', 'n3']].mean(axis=1)

# %%
# Найдём пары с наибольшими расхождениями между минимальной и максимальной оценками
expert_annotations['score_range'] = expert_annotations[['n1', 'n2', 'n3']].max(axis=1) - expert_annotations[['n1', 'n2', 'n3']].min(axis=1)
discrepancies = expert_annotations[expert_annotations['score_range'] > 2]
print(f"Количество строк с большими расхождениями: {len(discrepancies)}")
display(expert_annotations[expert_annotations['score_range'] > 2])
# Out:
# Количество строк с большими расхождениями: 3
#                           image                     query_id  n1  n2  n3  \
# 3956  3388330419_85d72f7cda.jpg  3358558292_6ab14193ed.jpg#2   1   2   4
# 5561   542179694_e170e9e465.jpg   300577375_26cc2773a1.jpg#2   1   2   4
# 5573   542317719_ed4dd95dc2.jpg   542317719_ed4dd95dc2.jpg#2   1   4   4
#
#       aggregated_score  score_range
# 3956          2.333333            3
# 5561          2.333333            3
# 5573          3.000000            3

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Обрати внимание что в последней паре изображение идеально соответствует описанию (название изображения входит в querry_id). Очевидно, что первый эксперт просто ошибся. Я бы не стал удалять такой пример.
#
# Или здесь бы как раз хорошо сработал метод большиства.
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# Просто попытка сыграть не как предложено, поиск альтернативных вариантов.
# </div>

# %% [markdown]
# - Эти строки содержат сильные разногласия, что делает их потенциально шумными для обучения модели. Удаление таких строк может улучшить качество данных.

# %%
# Удалим строки с шумом
expert_annotations = expert_annotations[expert_annotations['score_range'] <= 2]
print(f"Количество оставшихся строк: {len(expert_annotations)}")
# Out:
# Количество оставшихся строк: 5819

# %%
# Распределение итоговой агрегированной оценки:

# Подсчитываем количество каждой доли с помощью value_counts
expert_counts = expert_annotations['aggregated_score'].round(2).value_counts().sort_index()

# Вывод информации текстом
print("Анализ распределения экспертных оценок:")
for percentage, count in expert_counts.items():
    print(f"{percentage}%: {count} ответов")

print(f"\nОбщее количество ответов: {expert_counts.sum()}")

plt.hist(expert_annotations['aggregated_score'], bins=20, alpha=0.7, color='blue')
plt.title('Распределение агрегированных оценок')
plt.xlabel('Оценка')
plt.ylabel('Частота')
plt.show()
# Out:
# Анализ распределения экспертных оценок:
# 1.0%: 2350 ответов
# 1.33%: 965 ответов
# 1.67%: 689 ответов
# 2.0%: 678 ответов
# 2.33%: 322 ответов
# 2.67%: 193 ответов
# 3.0%: 240 ответов
# 3.33%: 75 ответов
# 3.67%: 60 ответов
# 4.0%: 247 ответов
#
# Общее количество ответов: 5819

# %% [markdown]
# **Выводы:**
#
# 1. **Данные краудсорсинга:**
#    - Большинство оценок краудсорсинга (почти 88%) сосредоточено в районе **0%**, что указывает на низкую вероятность соответствия текстов и изображений по мнению исполнителей.
#    - Оценки выше **66%** встречаются реже, что подтверждает: в наборе данных значительная часть пар "изображение-текст" воспринимается как несоответствующие.
#    - Средняя вероятность соответствия по краудсорсинговым данным невелика, что согласуется с общей тенденцией преобладания низких оценок.<BR></BR>
#
# 2. **Данные экспертов:**
#    - Экспертные оценки более равномерно распределены, что делает их более детализированными и ценными для анализа.
#    - Наиболее часто встречающиеся значения: **1.0 (40%)** и **2.0 (11.7%)**, что также указывает на преимущественно низкие оценки.
#    - Оценки **3.0 и выше** составляют около 10% данных, что подтверждает редкость полностью соответствующих пар "изображение-текст".<BR></BR>
#
# 3. **Необходимость нормализации:**
#    - Экспертные оценки варьируются от 1 до 4, и их нужно нормализовать в диапазон [0, 1], чтобы быть сопоставимыми с краудсорсинговыми данными.
#    - Это позволит объединить обе оценки в общую целевую переменную.<BR></BR>
#
# 4. **Рекомендации по объединению:**
#    - Для создания целевой переменной можно использовать взвешенное среднее:
#      - **60% веса от экспертов**, так как их данные более детализированы.
#      - **40% веса от краудсорсинга**, чтобы учесть мнения широкой аудитории.

# %%
# Нормализация экспертных оценок
# Создаём явную копию DataFrame
expert_annotations = expert_annotations.copy()

# Нормализация экспертных оценок
expert_annotations.loc[:, 'normalized_score'] = (expert_annotations['aggregated_score'] - 1) / 3

# Проверка результата
display(expert_annotations[['aggregated_score', 'normalized_score']].round(2).head())
# Out:
#    aggregated_score  normalized_score
# 0              1.00              0.00
# 1              1.33              0.11
# 2              1.33              0.11
# 3              1.67              0.22
# 4              1.33              0.11

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#  👍 </div>

# %%
# Проверим на графике
plt.hist(expert_annotations['aggregated_score'], bins=20, alpha=0.7, color='blue')
plt.title('Распределение агрегированных оценок')
plt.xlabel('Оценка')
plt.ylabel('Частота')
plt.show()

plt.hist(expert_annotations['normalized_score'], bins=20, alpha=0.7, color='blue')
plt.title('Распределение нормализованных оценок')
plt.xlabel('Оценка')
plt.ylabel('Частота')
plt.show()

# %% [markdown]
# Оценки нормализованы в диапазон [0, 1], перейдём к объединению согласно рекомендациям.</BR>
# Для объединения оценок, сопоставим строки в crowd_annotations и expert_annotations по полю `query_id`(дополнительный ключ) и `image` (основной ключ).</BR>
# </BR>
# Формула объединения: **final_score = 0.6 × expert_score + 0.4 × crowd_score**</BR>
# </BR>
# Это позволит учесть как точность экспертов, так и разнообразие мнений краудсорсинга.</BR>

# %%
# Объединяем данные по query_id и image
merged_data = pd.merge(
    expert_annotations, 
    crowd_annotations, 
    on=['query_id', 'image'],  # Используем query_id и image как ключи
    how='outer'  # Используем outer join, чтобы сохранить все строки, даже если данные не совпадают
)

# Переименовываем столбцы
merged_data = merged_data.rename(columns={
    'positive': 'crowd_score',
    'normalized_score': 'expert_score'
})

# Проверяем на наличие пропущенных значений (NaN)
print("Пропущенные значения в expert_score:", merged_data['expert_score'].isna().sum())
print("Пропущенные значения в crowd_score:", merged_data['crowd_score'].isna().sum())

# Логика расчёта итоговой оценки
def calculate_final_score(row):
    expert_score = row['expert_score']
    crowd_score = row['crowd_score']
    
    # Если оба значения отсутствуют, возвращаем NaN
    if pd.isna(expert_score) and pd.isna(crowd_score):
        return np.nan
    
    # Если есть только экспертная оценка, используем её
    if pd.isna(crowd_score):
        return expert_score
    
    # Если есть только краудсорсинговая оценка, используем её
    if pd.isna(expert_score):
        return crowd_score
    
    # Если обе оценки присутствуют, вычисляем взвешенное среднее
    return 0.6 * expert_score + 0.4 * crowd_score

# Применяем функцию для расчёта итоговой оценки
merged_data['final_score'] = merged_data.apply(calculate_final_score, axis=1)

# Удаляем строки, где final_score равно NaN
rows_before = len(merged_data)
merged_data = merged_data.dropna(subset=['final_score'])
rows_after = len(merged_data)

# Выводим количество удалённых строк
print(f"Количество удалённых строк с NaN в final_score: {rows_before - rows_after}")

# Оставляем только необходимые столбцы
merged_data = merged_data[['query_id', 'image', 'expert_score', 'crowd_score', 'final_score']]

# Отображаем результат
print("Итоговый набор данных:")
display(merged_data.head(10))
# Out:
# Пропущенные значения в expert_score: 45502
# Пропущенные значения в crowd_score: 3491
# Количество удалённых строк с NaN в final_score: 0
# Итоговый набор данных:
#                       query_id                      image  expert_score  \
# 0  1056338697_4f7d7ce270.jpg#2  1056338697_4f7d7ce270.jpg           NaN
# 1  1056338697_4f7d7ce270.jpg#2  2182488373_df73c7cc09.jpg           NaN
# 2  1056338697_4f7d7ce270.jpg#2  2594042571_2e4666507e.jpg           NaN
# 3  1056338697_4f7d7ce270.jpg#2  2647049174_0fb47cee2e.jpg           0.0
# 4  1056338697_4f7d7ce270.jpg#2  2843695880_eeea6c67db.jpg           NaN
# 5  1056338697_4f7d7ce270.jpg#2  2892995070_39f3c9a56e.jpg           NaN
# 6  1056338697_4f7d7ce270.jpg#2  2934359101_cdf57442dc.jpg           NaN
# 7  1056338697_4f7d7ce270.jpg#2  2981702521_2459f2c1c4.jpg           NaN
# 8  1056338697_4f7d7ce270.jpg#2   311146855_0b65fdb169.jpg           NaN
# 9  1056338697_4f7d7ce270.jpg#2  3197981073_3156963446.jpg           NaN
#
# ...

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#
# По объединению экспертных и крауд оценок все ОК, но подсвечу возможные альтернативы
#
# --------------
#
#
# В этом проекте есть несколько возможных стратегий работы с обучающими и краудсорс оценками,  вот эти стратегии с плюсами и минусами:
#
#
#    - использовать соединение через outer, в этом случае, при корректной обработке пропусков мы можем получить более 50К размеченых пар. К плюсам данного подхода можно отнести большое количество данных. Минус - в основном это будут данные, размеченные краудсорсерами, а там качество раметки ниже.
#    - использовать только экспертные оценки. плюс - высокое качество данных (разметка имеет шкалу). Минус - данных меньше.  Поясню по поводу качества разметки на примере: если на изображении одна собака, а в описании "две собаки бегут по берегу", то эксперты поставять соответствие 0,6-0,7 (переводя в шкалу 0-1), а краудсорсеры поставят 0.  Но на экспертных оценках модель хотя-бы научится находить собак, а на краудсор оценках ничему не начится.
#
#    - использование соединения через left.  Данный подход очевидно проигрывает второму варианту: данных столько же, нужно дополнительно возиться с объединением, но качество разметки снижается.. Но это соответсвует предложениям авторов проекта, поэтому такой подход имеет право на жизнь
#
#    - объединение через inner. Тут все плохо - и данных ОЧЕНЬ мало (в два раза меньше, чем использовать только экспертные оценки) и качество у них "подпорчено". И навыков по обработке пропусков не получаем.....
#
#
# ------------------
#
# Если говорить о моих предпочтениях, то я рекомендую работать с небольшим, но качественным набором - экспертными оценками.
#
# </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
#
# Скажу честно, при чтении проекта у меня возникает четкое ощущение что он был написан ChatGPT.
#
# Код достаточно красивый, но без учета контекста конкретного прокта и очень "общо".
#
#  - откуда возникли бесконечные значения, которых мы вдруг боимся? ты же только что исследовал распределение экспертных и крауд оценок?
#  - оба значения (экспертные и крауд) быть NaN просто исходя из технологии объединения
#
#
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# Написано с использованием, правда не ChatGPT, пользуюсь DeepSeek, в том числе для накидывания идей.<br>
# Инфины просто возникли в ошибках в какой-то момент и не мог от них избавиться...
# </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
# А вот логика рассчета итоговой оценки к сожалению содержит ошибку.   Её хорошо видно вот на нулевой  строке датафрейма
#
# ```
# 1056338697_4f7d7ce270.jpg#2	1056338697_4f7d7ce270.jpg	NaN	1.0	0.4
# ```
#
# Изображение и описание ИДЕАЛЬНО соответтсвуют друг другу (точнее описание написано для конкретного изображения. Краудсорсеры дали оценку 1. Казалось бы итоговая оценка тоже должна быть 1, ведь они "созданы друг для друга". Но итоговая оценка равна 0.4, что даже меньше чем 0.5 и это сходство мы можем трактовать как "отдаленно похоже, есть общие элементы".
#
# Причина в обработке пропусков. Если есть пропуск в экспертной оценке, то нужо использовать крауд оценку. Если есть пропуски в крауд оценках, то экспертные. А брать взвешенное среднее стоит если обе оценки известны.
#
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# Вот сейчас у меня ощущения эффекта Манделы. Чувство что было описание веса оценок.<br>
# Логика кажется логичной. Давай пересчитаем.
# </div>

# %%
# Гистограмма распределения final_score
sns.histplot(merged_data['final_score'], bins=20, kde=True)
plt.title('Распределение итоговых оценок (final_score)')
plt.xlabel('Итоговая оценка')
plt.ylabel('Количество')
plt.show()

# Анализ пропущенных значений
print("Пропущенные значения в expert_score:", merged_data['expert_score'].isna().sum())
print("Пропущенные значения в crowd_score:", merged_data['crowd_score'].isna().sum())

# Разделение данных на группы (например, по источникам оценок)
expert_scores = merged_data['expert_score'].dropna()
crowd_scores = merged_data['crowd_score'].dropna()

# Визуализация распределения оценок по группам
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.histplot(expert_scores, bins=20, kde=True, color='blue')
plt.title('Распределение expert_score')
plt.xlabel('Оценка эксперта')
plt.ylabel('Количество')

plt.subplot(1, 2, 2)
sns.histplot(crowd_scores, bins=20, kde=True, color='orange')
plt.title('Распределение crowd_score')
plt.xlabel('Оценка краудсорсинга')
plt.ylabel('Количество')

plt.tight_layout()
plt.show()
# Out:
# Пропущенные значения в expert_score: 45502
# Пропущенные значения в crowd_score: 3491

# %% [markdown]
# Создана финальная целевая переменная `final_score`.</BR>
# Большинство оценок находятся в нижней части диапазона, что может указывать на проблемы с качеством данных.</BR>
# Для балансировки данных попробуем прибегнуть к oversampling.

# %%
# заменим Boxplot на violinplot итоговых оценок
sns.violinplot(x=merged_data['final_score'])
plt.title('Violinplot итоговых оценок (final_score)')
plt.xlabel('Итоговая оценка')
plt.show()

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# Переделал усы на скрипку
# </div>

# %% [markdown]
# Так как, большинство алгоритмов машинного обучения не могут работать с пропущенными значениями (NaN). Воткнём небольшой компенсатор для данных.
#
# **Логика компенсатора следующая:**
# 1. Добавляем столбец compensation заполняется нулями.
# 2. Если expert_score равен NaN, заменяем NaN на -0.6 и добавляем 0.6 в столбец compensation.
# 3. Если crowd_score равен NaN, заменяем NaN на -0.4 и добавляем 0.4 в столбец compensation.
#
# Компенсаторный столбец compensation позволяет отслеживать, какие данные отсутствовали.

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# скажу честно, я совсем не понял идеи этого компенсаторого столбца.
#
# Как корректно работать с пропусками, без усложнений написал выше.
#
# Я бы просто убрал этот раздел, т.к. я не вижу чтобы ты как-то использовал эту оценку для обученя модели.
#
#
#
#
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# Идея была для проверки, но где-то на этапах она выветрилась и не актуальна.
# </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
#
# не стоит плодить лишние сущности. Я вижу что ты до конца проекта "тянешь" за собой четыре вида оценок.   Советую убрать лишнее, оставить только одну итоговую оценку соответствия, которую ты собрал из всех доступных, а все промежуточне убрать.
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# Подправил
# </div>

# %%
print(f"Уникальные изображения в train_dataset: {train_dataset['image'].nunique()}")
print(f"Уникальные изображения в crowd_annotations: {crowd_annotations['image'].nunique()}")
print(f"Уникальные изображения в expert_annotations: {expert_annotations['image'].nunique()}")
print(f"Уникальные query_id в train_dataset: {train_dataset['query_id'].nunique()}")
print(f"Уникальные query_id в crowd_annotations: {crowd_annotations['query_id'].nunique()}")
print(f"Уникальные query_id в expert_annotations: {expert_annotations['query_id'].nunique()}")
# Out:
# Уникальные изображения в train_dataset: 1000
# Уникальные изображения в crowd_annotations: 1000
# Уникальные изображения в expert_annotations: 1000
# Уникальные query_id в train_dataset: 977
# Уникальные query_id в crowd_annotations: 1000
# Уникальные query_id в expert_annotations: 977

# %%
# Создаём временный датафрейм с уникальными query_id и query_text
query_text_mapping = train_dataset[['query_id', 'query_text']].drop_duplicates()

# %%
# Добавляем query_text в merged_data
merged_data_with_text = pd.merge(
    merged_data,
    query_text_mapping,
    on='query_id',
    how='left'  # Используем left join, чтобы сохранить все строки из merged_data
)

# Проверяем пропуски в query_text
print("Пропуски в query_text после объединения:", merged_data_with_text['query_text'].isna().sum())
# Out:
# Пропуски в query_text после объединения: 1109

# %%
# Создаём train_merged_data с нужными столбцами
train_merged_data = merged_data_with_text[['image', 'query_id', 'query_text', 'final_score']]

# Проверяем пропуски
print("Пропуски в train_merged_data:")
# Общее количество строк до удаления
total_rows_before = len(train_merged_data)

# Проверяем, есть ли пропуски
if train_merged_data.isna().sum().any():
    # Если пропуски есть, удаляем строки с пропусками
    train_merged_data = train_merged_data.dropna()
    
    # Количество строк после удаления
    total_rows_after = len(train_merged_data)
    
    # Количество удалённых строк
    rows_deleted = total_rows_before - total_rows_after
    
    # Выводим результаты
    print(f"Строк после удаления: {total_rows_after}, Удалено:{rows_deleted} строк")
else:
    # Если пропусков нет, просто выводим общее количество строк
    print(f"Пропусков нет. всего строк: {total_rows_before}")

# Проверка итогового набора данных
display(train_merged_data.head())
# Out:
# Пропуски в train_merged_data:
# Строк после удаления: 50212, Удалено:1109 строк
#                        image                     query_id  \
# 0  1056338697_4f7d7ce270.jpg  1056338697_4f7d7ce270.jpg#2
# 1  2182488373_df73c7cc09.jpg  1056338697_4f7d7ce270.jpg#2
# 2  2594042571_2e4666507e.jpg  1056338697_4f7d7ce270.jpg#2
# 3  2647049174_0fb47cee2e.jpg  1056338697_4f7d7ce270.jpg#2
# 4  2843695880_eeea6c67db.jpg  1056338697_4f7d7ce270.jpg#2
#
#                                           query_text  final_score
# 0  A woman is signaling is to traffic , as seen f...          1.0
# 1  A woman is signaling is to traffic , as seen f...          0.0
# 2  A woman is signaling is to traffic , as seen f...          0.0
# 3  A woman is signaling is to traffic , as seen f...          0.0
# 4  A woman is signaling is to traffic , as seen f...          0.0

# %%
# Группировка и визуализация данных
def plot_final_score_distribution(data):
    """Функция для построения круговой диаграммы распределения final_score."""
    bins = [0, 0.2, 0.4, 0.6, 0.8, 1]
    labels = ['0.0 to 0.2', '0.2 to 0.4', '0.4 to 0.6', '0.6 to 0.8', '0.8 to 1']
    final_score_distribution = pd.cut(data['final_score'], bins=bins, labels=labels).value_counts()

    if final_score_distribution.empty:
        print("Нет данных для построения диаграммы.")
        return

    # Строим круговую диаграмму
    plt.figure(figsize=(12, 8))
    plt.pie(
        final_score_distribution, 
        labels=final_score_distribution.index, 
        autopct='%1.1f%%', 
        startangle=140, 
        colors=plt.cm.Paired.colors
    )
    plt.title('Распределение по группам final_score')
    plt.show()

def plot_final_score_histogram(data):
    """Функция для построения гистограммы распределения final_score."""
    plt.figure(figsize=(10, 6))
    sns.histplot(data['final_score'], bins=20, kde=True)
    plt.title('Распределение итоговых оценок (final_score)')
    plt.xlabel('Итоговая оценка')
    plt.ylabel('Количество')
    plt.show()

# %%
# Строим круговую диаграмму
plot_final_score_distribution(train_merged_data)

# %%
# Распределение итоговых оценок
plot_final_score_histogram(train_merged_data)

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
#
# К сожалению работать с проктом в таком виде очень сложно.. Постарайся его как-то структурировать.
#
# Одна ячейка занимает экран и вывод графика еще экран.
#
# Я пишу комментарий, а чтобы увидеть кусок кода, к которому он относится нужно сильно крутить туда-сюда.
#
# Я даже не представляю как ты делал его отладку....
#
# ---------------------
#
# Предметно:
#
# Давай подумаем, в чем смысл вот этого объединения:
#
# ```python
# train_merged_data = pd.merge(
# train_dataset,
# merged_data[['image', 'query_id', 'expert_score', 'crowd_score', 'compensation', 'final_score']],
# on=['image', 'query_id'],
# how='outer'  # Используем outer join для сохранения всех строк
# )
#
# ```
#
# У тебя уже есть датафрейм, в котором есть изображения/id описания и оценки.
#
# Для полного счасться нам не хватает только расшифровки описаний.
#
# Но содединяя датафреймы ты не добавишь эти описания, точнее они будут полны пропусков.
#
# Гораздо эффективнее и проще создать "временный" датафрейм уникальными парами query_id/query_text и восстановить query_text по уникальному query_id  в датафрейме с оценками
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# 4К разрешение...<br>
#     Подправил
# </div>

# %%
# Проверка на пропуски после удаления строк
print("\nПроверка на пропуски:")
print(train_merged_data.isna().sum())

# Проверка на дубликаты
print("\nПроверка на дубликаты:")
duplicates = train_merged_data.duplicated().sum()
print(f"Количество дубликатов: {duplicates}")

# Удаление дубликатов (если они есть) и сброс индексов
if duplicates > 0:
    train_merged_data = train_merged_data.drop_duplicates().reset_index(drop=True)
    print(f"Дубликаты удалены. Новый размер набора данных: {train_merged_data.shape}")
else:
    print("Дубликаты не обнаружены.")

# Вывод информации об уникальных значениях
print("\nУникальные значения в данных:")
print(f"Уникальные image в train_merged_data: {train_merged_data['image'].nunique()}")
print(f"Уникальные query_id в train_merged_data: {train_merged_data['query_id'].nunique()}")
print(f"Уникальные query_text: {train_merged_data['query_text'].nunique()}")

# Проверка итогового набора данных
print("\nИтоговый набор данных:")
display(train_merged_data.head())
print(f"Размер итогового набора данных: {train_merged_data.shape}")
# Out:
# Проверка на пропуски:
# image          0
# query_id       0
# query_text     0
# final_score    0
# dtype: int64
#
# Проверка на дубликаты:
# Количество дубликатов: 0
# Дубликаты не обнаружены.
#
# Уникальные значения в данных:
# Уникальные image в train_merged_data: 1000
# Уникальные query_id в train_merged_data: 977
# Уникальные query_text: 977
#
# Итоговый набор данных:
#                        image                     query_id  \
# 0  1056338697_4f7d7ce270.jpg  1056338697_4f7d7ce270.jpg#2
# 1  2182488373_df73c7cc09.jpg  1056338697_4f7d7ce270.jpg#2
# 2  2594042571_2e4666507e.jpg  1056338697_4f7d7ce270.jpg#2
# 3  2647049174_0fb47cee2e.jpg  1056338697_4f7d7ce270.jpg#2
# 4  2843695880_eeea6c67db.jpg  1056338697_4f7d7ce270.jpg#2
#
#                                           query_text  final_score
# 0  A woman is signaling is to traffic , as seen f...          1.0
# 1  A woman is signaling is to traffic , as seen f...          0.0
# ...

# %%
train_merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 50212 entries, 0 to 51320
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   image        50212 non-null  object
#  1   query_id     50212 non-null  object
#  2   query_text   50212 non-null  object
#  3   final_score  50212 non-null  float64
# dtypes: float64(1), object(3)
# memory usage: 1.9+ MB

# %% [markdown]
# ##### **Выводы:**
#
# 1. **Проверка на пропуски:**
#    - Данные не содержат пропусков. Все столбцы (`image`, `query_id`, `query_text`, `final_score`) заполнены, что подтверждает корректность предобработки.<br>
#    - Объекты (строки): image, query_id, query_text.
#    - Числовые значения (float): expert_score, crowd_score, compensation, final_score.<br>
# <br>
# 2. **Распределение по группам `final_score`:**
#    - 45.4% данных — низкие оценки (0.0 to 0.2).
#    - 19.4% — умеренные оценки (0.2 to 0.4).
#    - 3.8% — хорошие оценки (0.4 to 0.6).
#    - 15.8% — высокие оценки (0.6 to 0.8).
#    - 15.6% — полностью соответствующие пары (0.8 to 1).<br>
# <br>
# 3. **Анализ данных:**
#    - Уникальные query_id в train_merged_data: 977
#    - Уникальные query_text: 977
#    - Размер набора данных: 50212 строк и 4 столбцов, что достаточно для дальнейшего анализа.<br>
# <br>
# 4. **Завершение первого этапа:**
#    - Данные загружены, проверены и обработаны.
#    - Экспертные и краудсорсинговые оценки агрегированы и нормализованы.
#    - Целевая переменная (`final_score`) рассчитана и приведена к диапазону от 0 до 1.
#    - Данные объединены и готовы для следующего этапа.
#    - Лишние столбцы удалены

# %% [markdown]
# ## 2. Проверка данных
#
# В некоторых странах, где работает ваша компания, действуют ограничения по обработке изображений: поисковым сервисам и сервисам, предоставляющим возможность поиска, запрещено без разрешения родителей или законных представителей предоставлять любую информацию, в том числе, но не исключительно тексты, изображения, видео и аудио, содержащие описание, изображение или запись голоса детей. Ребёнком считается любой человек, не достигший 16 лет.
#
# В вашем сервисе строго следуют законам стран, в которых работают. Поэтому при попытке посмотреть изображения, запрещённые законодательством, вместо картинок показывается дисклеймер:
#
# > This image is unavailable in your country in compliance with local laws
# >
#
# Однако у вас в PoC нет возможности воспользоваться данным функционалом. Поэтому все изображения, которые нарушают данный закон, нужно удалить из обучающей выборки.

# %%
# Уточнённое регулярное выражение для фильтрации
stop_words_regex = r'\b(?:boy|boys|girl|girls|child|children|teenage|teenager|teenagers|kid|kids|baby|babies)\b'

# Находим индексы строк, содержащих стоп-слова
stop_words_indices = set(train_merged_data[train_merged_data['query_text'].str.contains(stop_words_regex, case=False, regex=True, na=False)].index)

# Преобразуем множество stop_words_indices в список
stop_words_indices_list = list(stop_words_indices)

# Собираем query_id строк, содержащих стоп-слова
bad_query_ids = set(train_merged_data.loc[stop_words_indices_list, 'query_id'])

# Удаляем все строки, связанные с этими query_id
train_cleaned_data = train_merged_data[~train_merged_data['query_id'].isin(bad_query_ids)].reset_index(drop=True)
# Сохранение удалённых строк
removed_rows = train_merged_data[train_merged_data['query_id'].isin(bad_query_ids)]

# Вывод статистики
print(f"Удалено строк: {len(removed_rows)}")
print(f"Осталось строк: {len(train_cleaned_data)}")
print()
print(f"Уникальные изображения в train_dataset: {train_cleaned_data['image'].nunique()}")
print(f"Уникальные query_id в train_dataset: {train_cleaned_data['query_id'].nunique()}")
print(f"Размер итогового набора данных: {train_cleaned_data.shape}")

# Пример удалённых строк
print("\nПример удалённых строк:")
display(removed_rows.sample(10))

# Анализ частоты стоп-слов
all_words = ' '.join(train_cleaned_data['query_text']).lower().split()
stop_words_counts = Counter(word for word in all_words if re.match(stop_words_regex, word))
print("\nЧастота стоп-слов:")
print(stop_words_counts.most_common(10))
# Out:
# Удалено строк: 14089
# Осталось строк: 36123
#
# Уникальные изображения в train_dataset: 1000
# Уникальные query_id в train_dataset: 692
# Размер итогового набора данных: (36123, 4)
#
# Пример удалённых строк:
#                            image                     query_id  \
# 32663  1836335410_de8313a64e.jpg  3280052365_c4644bf0a5.jpg#2
# 4298   1122944218_8eb3607403.jpg  1682079482_9a72fa57fa.jpg#2
# 1507   3655155990_b0e201dd3c.jpg  1298295313_db1f4c6522.jpg#2
# 20181  3095225232_2e6e6dc92e.jpg  2844641033_dab3715a99.jpg#2
# 14129  2797149878_bb8e27ecf9.jpg  2510020918_b2ca0fb2aa.jpg#2
# 17366  3530843182_35af2c821c.jpg  2660008870_b672a4c76a.jpg#2
# 2921   2526041608_a9775ab8d7.jpg  1446053356_a924b4893f.jpg#2
# 51244   468102269_135938e209.jpg   968081289_cdba83ce2e.jpg#2
# 2909   1446053356_a924b4893f.jpg  1446053356_a924b4893f.jpg#2
# 6944   2621415349_ef1a7e73be.jpg  2128119486_4407061c40.jpg#2
#
#                                               query_text  final_score
# ...

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
# Обычно при чистке датасета от детского контента уходит около 30%.
#
# У тебя же потерялось 90% данных.
#
# Насколько я разобрался в коде, на первом шаге (где ты используешь .str.contains) ты верно определяешь строки, где в описании упоминаются дети.
#
# Но вот цикл с разделением на слова ломает тебе все.
#
# Простой пример:
#
# Фраза: 'A woman is signaling is to traffic , as seen from behind .'
# Превращается в последовательность токенов ['a', 'woman', 'is', 'signaling', 'is', 'to', 'traffic', 'as', 'seen','from','behind'].
#
#  Дальше ты проверяешь каждую фразу на вхождение и оказываетя что `'a' in stop_words_regex` возвращает True.
#
#
#
# </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
#
# Ты удаляешь комментарии, в которых есть слова, обозначающие детей. Но наша задача убрать изображения, содержащие детей. Есть два способа сделать это:
#
#  - Определить список плохих изображений, как изображения удовлетворяющие условиям:
#     - Комментарий содержит плохие слова
#     - <b>Оценка соответствия комментария и изображения выше порога.</b>
#  - Удалить из нашего датасета все пары "изображение/описание" с плохими изображениями.
#
#
# И второй, очень красивый способ. Он основан на том, что `query_id` содержит в с себе имя изображения, для которого он был написан (такая пасхалочка от авторов датасета).
#
#  - Определить список плохих комментариев
#  - У `query_id`  плохих комментариев отрезать два последних символа и получим список плохих изображений.
#
#
#
#
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# Подправил, теперь вроде потери поменьше.
# </div>

# %%
sns.histplot(train_cleaned_data['final_score'], bins=20, kde=True)
plt.title('Распределение итоговых оценок (final_score)')
plt.xlabel('Итоговая оценка')
plt.ylabel('Количество')
plt.show()

# %% [markdown]
# **Было:** Удаление более 90% данных — это большая потеря, но при этом не изменилось распределение.
#
# **Стало:** Удалено 28.06% строк.

# %% [markdown]
# ## 3. Векторизация изображений
#
# Перейдём к векторизации изображений.
#
# Самый примитивный способ — прочесть изображение и превратить полученную матрицу в вектор. Такой способ нам не подходит: длина векторов может быть сильно разной, так как размеры изображений разные. Поэтому стоит обратиться к свёрточным сетям: они позволяют "выделить" главные компоненты изображений. Как это сделать? Нужно выбрать какую-либо архитектуру, например ResNet-18, посмотреть на слои и исключить полносвязные слои, которые отвечают за конечное предсказание. При этом можно загрузить модель данной архитектуры, предварительно натренированную на датасете ImageNet.

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
# Что это такое? Похоже на старый код, который ты первёл в маркдаун ячейки.
#
# Пожалуйста удали всё лишнее из проекта.
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
#     Такой файл был изначально, в шапке ещё значился как <B>Сборный проект-4</B>.<br>
# Спрашивал у Куратора, но он так ничего и не ответил...
# </div>

# %%
# Инициализация модели ResNet-18
resnet = resnet18(weights=ResNet18_Weights.IMAGENET1K_V1)
resnet = torch.nn.Sequential(*list(resnet.children())[:-1])  # Исключаем полносвязные слои
resnet.eval();

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Если ты не специально выводишь все слои модели, то можно добавить точку с запятой после последней команды в ячейке.
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# Спасибо, иногда пользуюсь, тут видимо проспал...
# </div>

# %%
# Трансформация изображений для ResNet-18
norm = transforms.Normalize(
    mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
preprocess = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    norm,
])

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Я бы посоветовал использовать код из теории к этому спринту. Часть изображений в нашем датасете прямоугольные там это решается через вырезание квадрата из центра изображения.
#
# В твоем случае получится сжатие по одной из осей, а значит изменятся пропорции, что может ухудшить качество векторизации.
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# поправил
# </div>

# %%
# Функция для векторизации изображения с кэшированием
@lru_cache(maxsize=None)  # Кэшируем все результаты
def img_to_vect(image_path, model, preprocess):
    """Преобразует изображение в вектор с использованием ResNet-18."""
    try:
        image = Image.open(image_path).convert('RGB')
        image_tensor = preprocess(image).unsqueeze(0)  # Добавляем размерность batch
        with torch.no_grad():
            img_vector = model(image_tensor).flatten().numpy()
        return img_vector
    except Exception as e:
        print(f"Ошибка обработки изображения {image_path}: {e}")
        return None

# %%
# Функция для векторизации изображений в DataFrame
def df_img_vectorizer(df, img_folder_name):
    """Добавляет векторы изображений в DataFrame."""
    # Создаем словарь для хранения векторов уникальных изображений
    img_vector_cache = {}
    
    # Векторизация уникальных изображений
    unique_images = df['image'].unique()
    for image_name in unique_images:
        image_path = Path(img_folder_name) / image_name
        img_vector = img_to_vect(str(image_path), resnet, preprocess)
        img_vector_cache[image_name] = img_vector
    
    # Заполняем столбец 'img_vector' в DataFrame
    df['img_vector'] = df['image'].map(img_vector_cache)
    
    return df

# %%
# Использование train_cleaned_data
# Векторизация изображений
print("Векторизация изображений из train_cleaned_data...")
train_cleaned_data = df_img_vectorizer(train_cleaned_data, img_folder_name)

# Проверка результата
print(f"Обработано изображений: {len(train_cleaned_data)}")
display(train_cleaned_data.head())
# Out:
# Векторизация изображений из train_cleaned_data...
# Обработано изображений: 36123
#                        image                     query_id  \
# 0  1056338697_4f7d7ce270.jpg  1056338697_4f7d7ce270.jpg#2
# 1  2182488373_df73c7cc09.jpg  1056338697_4f7d7ce270.jpg#2
# 2  2594042571_2e4666507e.jpg  1056338697_4f7d7ce270.jpg#2
# 3  2647049174_0fb47cee2e.jpg  1056338697_4f7d7ce270.jpg#2
# 4  2843695880_eeea6c67db.jpg  1056338697_4f7d7ce270.jpg#2
#
#                                           query_text  final_score  \
# 0  A woman is signaling is to traffic , as seen f...          1.0
# 1  A woman is signaling is to traffic , as seen f...          0.0
# 2  A woman is signaling is to traffic , as seen f...          0.0
# 3  A woman is signaling is to traffic , as seen f...          0.0
# 4  A woman is signaling is to traffic , as seen f...          0.0
#
#                                           img_vector
# 0  [0.69398123, 3.0318162, 2.9169858, 0.9519205, ...
# ...

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# У нас не больше чем 1000 уникальных изображений, при этом ты прогоняешь изображения черз модель почти 5000 раз (а если бы не ошибка на предыдущем этапе, то и все 50 тысяч раз.
#
# Выходом может быть либо векторизация только уникальных изображений, либо использование кэширования.
#
# Советую почитать про lru_cache (легко гуглится и можно примнить к функции img_to_vect)
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# поправил
# </div>

# %% [markdown]
# **Векторизация изображений:**
#
# - Изображения преобразованы в векторы с использованием модели ResNet-18.
# - Векторы добавлены в датасет в колонку img_vector.
# - Обработано 4947 изображений, ошибок не возникло.

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Здесь все ОК, векторизация изображений произведена верно </div>

# %% [markdown]
# ## 4. Векторизация текстов
#
# Следующий этап — векторизация текстов.

# %%
# Загрузка предобученной модели BERT и токенизатора
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased", clean_up_tokenization_spaces=True)
bert_model = AutoModel.from_pretrained("bert-base-uncased")

# %%
# Функция для извлечения текстовых эмбеддингов с кэшированием
@lru_cache(maxsize=None)  # Кэшируем все результаты
def extract_text_features(text, tokenizer, bert_model):
    """Извлечение текстовых эмбеддингов с использованием BERT."""
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=128)
    with torch.no_grad():
        outputs = bert_model(**inputs)
        # Используем эмбеддинги CLS-токена
        features = outputs.last_hidden_state[:, 0, :].squeeze().numpy()
    return features

# %%
# Функция для векторизации текстов в DataFrame
def df_text_vectorizer(df, text_column, tokenizer, bert_model):
    """Добавление текстовых эмбеддингов в DataFrame."""
    # Создаем словарь для хранения векторов уникальных текстов
    text_vector_cache = {}
    
    # Векторизация уникальных текстов
    unique_texts = df[text_column].unique()
    for text in tqdm(unique_texts, desc="Векторизация текстов"):
        text_vector = extract_text_features(text, tokenizer, bert_model)
        text_vector_cache[text] = text_vector
    
    # Заполняем столбец 'text_vector' в DataFrame
    df['text_vector'] = df[text_column].map(text_vector_cache)
    
    return df

# %%
# Векторизация текстов в train_cleaned_data
print("Векторизация текстов из train_cleaned_data...")
train_cleaned_data = df_text_vectorizer(train_cleaned_data, 'query_text', tokenizer, bert_model)
# Out:
# Векторизация текстов из train_cleaned_data...
# Векторизация текстов: 100%|██████████████████████████████████████████████████████████| 692/692 [00:17<00:00, 38.55it/s]

# %%
# Проверка результата
print(f"Обработано текстов: {len(train_cleaned_data)}")
display(train_cleaned_data.head())
# Out:
# Обработано текстов: 36123
#                        image                     query_id  \
# 0  1056338697_4f7d7ce270.jpg  1056338697_4f7d7ce270.jpg#2
# 1  2182488373_df73c7cc09.jpg  1056338697_4f7d7ce270.jpg#2
# 2  2594042571_2e4666507e.jpg  1056338697_4f7d7ce270.jpg#2
# 3  2647049174_0fb47cee2e.jpg  1056338697_4f7d7ce270.jpg#2
# 4  2843695880_eeea6c67db.jpg  1056338697_4f7d7ce270.jpg#2
#
#                                           query_text  final_score  \
# 0  A woman is signaling is to traffic , as seen f...          1.0
# 1  A woman is signaling is to traffic , as seen f...          0.0
# 2  A woman is signaling is to traffic , as seen f...          0.0
# 3  A woman is signaling is to traffic , as seen f...          0.0
# 4  A woman is signaling is to traffic , as seen f...          0.0
#
#                                           img_vector  \
# 0  [0.69398123, 3.0318162, 2.9169858, 0.9519205, ...
# 1  [0.06986058, 4.2100725, 0.76644397, 0.7687497,...
# ...

# %% [markdown]
# **Векторизация текстов:**
#
# - Тексты преобразованы в векторы с использованием модели BERT.
# - Векторы добавлены в датасет в колонку text_vector.
# - Обработано 36123 текстов, ошибок не возникло.

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#  Отлично, вектра для изображений получены👍 </div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Проблемы с лишними операциями такие же как и при векторизации изображений.
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# поправил
# </div>

# %% [markdown]
# ## 5. Объединение векторов
#
# Подготовьте данные для обучения: объедините векторы изображений и векторы текстов с целевой переменной.

# %%
# Объединение векторов изображений и текстов
combined_features = np.concatenate(
    [train_cleaned_data['img_vector'].tolist(), train_cleaned_data['text_vector'].tolist()], 
    axis=1
)

# %%
# Добавление целевой переменной
target_variable = train_cleaned_data['final_score'].values

# Проверка результата
print(f"Размерность объединенных векторов: {combined_features.shape}")
print(f"Размерность целевой переменной: {target_variable.shape}")
# Out:
# Размерность объединенных векторов: (36123, 1280)
# Размерность целевой переменной: (36123,)

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#  Вектора, полученные из текста и изображения объеденены👍 </div>

# %% [markdown]
# **Итоги:**
# - Векторы изображений и текстов объединены в общий вектор размерности `(36123, 1280)`.
# - Целевая переменная (`final_score`) извлечена, размерность `(36123,)`.
# - Данные готовы для обучения модели.

# %% [markdown]
# ## 6. Обучение модели предсказания соответствия
#
# Для разбиения датасета на тренировочную и валидационную выборки в пропорции 7:3 используем метод GroupShuffleSplit из библиотеки sklearn.model_selection:

# %% [markdown]
# **Выбор модели**
# Для задачи предсказания `final_score` (регрессия) с учетом дисбаланса данных и мультимодальности (изображения + тексты) предлагается следующая гипотеза:
# <br>
# 1. **Градиентный бустинг (Gradient Boosting)**:
#    - Хорошо работает с табличными данными.
#    - Может учитывать сложные нелинейные зависимости.
#    - Поддерживает взвешивание объектов, что полезно для учета дисбаланса.
# <br>
# 2. **Случайный лес (Random Forest)**:
#    - Устойчив к переобучению.
#    - Легко интерпретируем.
#    - Может обрабатывать дисбаланс через балансировку классов.
# <br>
# 3. **Нейронная сеть (Neural Network)**:
#    - Способна учитывать сложные взаимосвязи между изображениями и текстами.
#    - Может быть адаптирована для работы с дисбалансом через кастомную функцию потерь.
#    - Подходит для задач с большим объемом данных.
# <br>
# <br>
# **Выбор метрики**
#
# Целевая переменная `final_score` — непрерывная, поэтому для оценки моделей используем:
# - **MSE (Mean Squared Error)**:
#   - Основная метрика для регрессии.
#   - Чувствительна к большим ошибкам.
# <br>
# - **Дополнительно**:
#   - **MAE (Mean Absolute Error)** — проще интерпретировать.
#   - **Взвешенный MSE** — чтобы учесть дисбаланс, увеличив вес редких высоких оценок.

# %% [markdown]
# **Разделение данных**

# %%
# Разделение данных с учетом групп (изображений)
gss = GroupShuffleSplit(n_splits=1, train_size=0.7, random_state=rnd_state)
train_indices, valid_indices = next(gss.split(
    X=combined_features, 
    y=target_variable, 
    groups=train_cleaned_data['image']
))

# Создание тренировочной и валидационной выборок
train_features, valid_features = combined_features[train_indices], combined_features[valid_indices]
train_targets, valid_targets = target_variable[train_indices], target_variable[valid_indices]

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
# Отлично, благодаря использованию GroupShuffleSplit ты исключаешь попадание одного изображения в обучающий и валидационный наборы.</div>

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# Только давай разберемся с выборками. Финальное тестирование (визуальное) мы делаем на отложенной выборке. Поэтому выборка,которую ты сейчас отделил играет роль валидационной. Есть смысл в её названии использовать слово valid а не test</div>

# %% [markdown]
#  <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# логично
# </div>

# %% [markdown]
# **Обучение Gradient Boosting**

# %%
# %%time
# Модель 1: Градиентный бустинг
gb_model = GradientBoostingRegressor(random_state=rnd_state, n_estimators=100, learning_rate=0.1, max_depth=3)
gb_model.fit(train_features, train_targets)

# Оценка качества
gb_predictions = gb_model.predict(valid_features)
gb_mse = mean_squared_error(valid_targets, gb_predictions)
gb_mae = mean_absolute_error(valid_targets, gb_predictions)

print(f"Gradient Boosting MSE: {gb_mse}")
print(f"Gradient Boosting MAE: {gb_mae}")
# Out:
# Gradient Boosting MSE: 0.04209128273181366
# Gradient Boosting MAE: 0.12794122914265119
# CPU times: total: 5min 49s
# Wall time: 5min 56s

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#  👍 </div>

# %% [markdown]
# **Обучение Random Forest**

# %%
# %%time
# Модель 2: Случайный лес (Жадный лес)
# Уменьшение размерности с помощью PCA
pca = PCA(n_components=100)  
features_reduced = pca.fit_transform(train_features)  # Уменьшаем размерность обучающих данных
valid_features_reduced = pca.transform(valid_features)  # Уменьшаем размерность валидационных данных

# Параметры для RandomizedSearchCV
param_grid = {
    'n_estimators': [50, 100, 150],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['sqrt', 'log2', None]  
}

# Создаем модель случайного леса
rf_model = RandomForestRegressor(random_state=rnd_state)

# Настраиваем RandomizedSearchCV
randomized_search = RandomizedSearchCV(
    estimator=rf_model,
    param_distributions=param_grid,
    n_iter=20,  
    cv=2,       
    scoring='neg_mean_squared_error',
    n_jobs=-1,
    random_state=rnd_state
)

# Запускаем поиск
randomized_search.fit(features_reduced, train_targets)

# Лучшая модель
best_rf_model = randomized_search.best_estimator_

# Предсказания на валидационной выборке
rf_predictions = best_rf_model.predict(valid_features_reduced) 

# Оценка качества
rf_mse = mean_squared_error(valid_targets, rf_predictions)
rf_mae = mean_absolute_error(valid_targets, rf_predictions)

print(f"Лучшие параметры: {randomized_search.best_params_}")
print(f"Random Forest MSE: {rf_mse}")
print(f"Random Forest MAE: {rf_mae}")
# Out:
# Лучшие параметры: {'n_estimators': 150, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 'log2', 'max_depth': 20}
# Random Forest MSE: 0.045479876974975464
# Random Forest MAE: 0.14415088251767508
# CPU times: total: 28.3 s
# Wall time: 6min 49s

# %% [markdown]
# <img src="https://emojigraph.org/media/apple/check-mark-button_2705.png" align=left width=33, heigth=33>
# <div class="alert alert-success">
#  👍 </div>

# %% [markdown]
# **Обучение нейронной сети**

# %%
# %%time
# Модель 3: Нейронная сеть
# Определение архитектуры нейронной сети
class NeuralNetwork(nn.Module):
    def __init__(self, input_shape):
        super(NeuralNetwork, self).__init__()
        self.fc1 = nn.Linear(input_shape, 128)
        self.dropout1 = nn.Dropout(0.3)
        self.fc2 = nn.Linear(128, 64)
        self.dropout2 = nn.Dropout(0.2)
        self.fc3 = nn.Linear(64, 32)
        self.fc4 = nn.Linear(32, 1)  # Выходной слой для регрессии

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = self.dropout1(x)
        x = torch.relu(self.fc2(x))
        x = self.dropout2(x)
        x = torch.relu(self.fc3(x))
        x = self.fc4(x)
        return x

# Проверка наличия GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Преобразование данных в тензоры и перемещение на устройство (GPU/CPU)
train_features_tensor = torch.tensor(train_features, dtype=torch.float32).to(device)
train_targets_tensor = torch.tensor(train_targets, dtype=torch.float32).view(-1, 1).to(device)
valid_features_tensor = torch.tensor(valid_features, dtype=torch.float32).to(device)
valid_targets_tensor = torch.tensor(valid_targets, dtype=torch.float32).view(-1, 1).to(device)

# Создание DataLoader
train_dataset = TensorDataset(train_features_tensor, train_targets_tensor)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)

valid_dataset = TensorDataset(valid_features_tensor, valid_targets_tensor)
valid_loader = DataLoader(valid_dataset, batch_size=32, shuffle=False)

# Инициализация модели и перемещение на устройство
input_shape = train_features.shape[1]
nn_model = NeuralNetwork(input_shape).to(device)

# Определение функции потерь и оптимизатора
criterion = nn.MSELoss()  
optimizer = optim.Adam(nn_model.parameters(), lr=0.001)  

# Обучение модели
num_epochs = 100
for epoch in range(num_epochs):
    nn_model.train() 
    running_loss = 0.0
    for inputs, targets in train_loader:
        inputs, targets = inputs.to(device), targets.to(device)  
        optimizer.zero_grad()
        outputs = nn_model(inputs)  
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    print(f"Epoch [{epoch + 1}/{num_epochs}], Loss: {running_loss / len(train_loader):.4f}")

# Оценка качества модели
nn_model.eval()  
nn_predictions = []  
with torch.no_grad():
    for inputs, _ in valid_loader:
        inputs = inputs.to(device)   
        outputs = nn_model(inputs)  
        nn_predictions.extend(outputs.cpu().numpy().flatten())   

# Вычисление метрик
nn_mse = mean_squared_error(valid_targets, nn_predictions)
nn_mae = mean_absolute_error(valid_targets, nn_predictions)

print(f"Neural Network MSE: {nn_mse:.4f}")
print(f"Neural Network MAE: {nn_mae:.4f}")
# Out:
# Epoch [1/100], Loss: 0.0480
# Epoch [2/100], Loss: 0.0467
# Epoch [3/100], Loss: 0.0460
# Epoch [4/100], Loss: 0.0455
# Epoch [5/100], Loss: 0.0454
# Epoch [6/100], Loss: 0.0449
# Epoch [7/100], Loss: 0.0443
# Epoch [8/100], Loss: 0.0441
# Epoch [9/100], Loss: 0.0438
# Epoch [10/100], Loss: 0.0436
# Epoch [11/100], Loss: 0.0433
# Epoch [12/100], Loss: 0.0430
# Epoch [13/100], Loss: 0.0431
# Epoch [14/100], Loss: 0.0428
# Epoch [15/100], Loss: 0.0427
# Epoch [16/100], Loss: 0.0422
# Epoch [17/100], Loss: 0.0425
# Epoch [18/100], Loss: 0.0419
# Epoch [19/100], Loss: 0.0422
# Epoch [20/100], Loss: 0.0418
# Epoch [21/100], Loss: 0.0419
# Epoch [22/100], Loss: 0.0417
# Epoch [23/100], Loss: 0.0414
# Epoch [24/100], Loss: 0.0413
# Epoch [25/100], Loss: 0.0415
# Epoch [26/100], Loss: 0.0416
# Epoch [27/100], Loss: 0.0413
# Epoch [28/100], Loss: 0.0416
# Epoch [29/100], Loss: 0.0414
# Epoch [30/100], Loss: 0.0413
# Epoch [31/100], Loss: 0.0409
# Epoch [32/100], Loss: 0.0409
# ...

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/ba/Warning_sign_4.0.png" align=left width=44, heigth=33>
# <div class="alert alert-warning">
# В самом начале проекта я тебе писал, что в одном проекте лучше использовать только один фреймворк.
#
# Для векторизации изображений ты использвал pytorch, для текстов тоже использовал модель с бэкендом pytorch, было бы логично и здесь тоже использовать модель pytorch, не обращаясь к Keras.
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# Скорректировал
# </div>

# %%
def plot_model_comparison(test_targets, gb_predictions, rf_predictions, nn_predictions, gb_mae, rf_mae, nn_mae):
    """
    Сравнение моделей: распределение ошибок и метрики MAE.
    """
    # График распределения ошибок
    plt.figure(figsize=(12, 6))
    
    # Ошибки для каждой модели
    gb_errors = test_targets - gb_predictions
    rf_errors = test_targets - rf_predictions
    nn_errors = test_targets - nn_predictions
    
    # Гистограмма ошибок
    sns.histplot(gb_errors, label='Gradient Boosting', kde=True, color='blue', alpha=0.6)
    sns.histplot(rf_errors, label='Random Forest', kde=True, color='green', alpha=0.6)
    sns.histplot(nn_errors, label='Neural Network', kde=True, color='red', alpha=0.6)
    
    plt.title('Распределение ошибок моделей', fontsize=16, fontweight='bold')
    plt.xlabel('Ошибка (разница между предсказанным и истинным значением)', fontsize=12)
    plt.ylabel('Частота', fontsize=12)
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.show()

    # Создание сравнительной таблицы
    mae_data = {
        'Model': ['Gradient Boosting', 'Random Forest', 'Neural Network'],
        'MAE': [gb_mae, rf_mae, nn_mae]
    }
    mae_df = pd.DataFrame(mae_data)
    
    # Вывод таблицы
    print("Сравнение моделей по метрике MAE:")
    display(mae_df)

    # Визуализация метрик MAE
    plt.figure(figsize=(10, 6))
    sns.barplot(x='Model', y='MAE', hue='Model', data=mae_df, palette=['#1f77b4', '#2ca02c', '#d62728'])
    plt.title('Сравнение моделей по метрике MAE', fontsize=16, fontweight='bold')
    plt.xlabel('Модель', fontsize=12)
    plt.ylabel('Mean Absolute Error (MAE)', fontsize=12)
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.tight_layout()

    # Добавление значений MAE на график
    for index, row in mae_df.iterrows():
        plt.text(index, row['MAE'] + 0.001, f'{row["MAE"]:.4f}', ha='center', va='bottom', fontsize=12)

    plt.show()

# %%
plot_model_comparison(valid_targets, gb_predictions, rf_predictions, nn_predictions, gb_mae, rf_mae, nn_mae)
# Out:
# Сравнение моделей по метрике MAE:
#                Model       MAE
# 0  Gradient Boosting  0.127941
# 1      Random Forest  0.144151
# 2     Neural Network  0.122982

# %% [markdown]
# #### Сравнение моделей по метрике MAE:
#
# 1. **Gradient Boosting**:
#    - **MAE**: 0.127941
#    - **Вывод**: Показывает наилучшую точность среди всех моделей. Это делает его оптимальным выбором для задач, где важна минимальная ошибка. Gradient Boosting хорошо справляется с нелинейными зависимостями и сложными структурами данных.
#
# 2. **Neural Network**:
#    - **MAE**: 0.124962
#    - **Вывод**: Близок к Gradient Boosting по точности, но требует больше вычислительных ресурсов и времени для обучения. Нейронная сеть может быть полезна для задач с высокой сложностью, где другие модели не справляются.
#
# 3. **Random Forest**:
#    - **MAE**: 0.144151
#    - **Вывод**: Уступает по точности Gradient Boosting и Neural Network, но остаётся устойчивой моделью, менее склонной к переобучению. Random Forest подходит для задач, где важна надёжность и интерпретируемость.

# %% [markdown]
# ## 7. Тестирование модели
#
# Настало время протестировать модель. Для этого получите эмбеддинги для всех тестовых изображений из папки `test_images`, выберите случайные 10 запросов из файла `test_queries.csv` и для каждого запроса выведите наиболее релевантное изображение. Сравните визуально качество поиска.

# %%
def test_model(test_queries, test_images_folder, models, tokenizer, bert_model, preprocess, image_model, num_queries=10):
    """
    Тестирование модели на тестовых данных.
    
    Параметры:
    - test_queries: DataFrame с тестовыми запросами.
    - test_images_folder: Путь к папке с тестовыми изображениями.
    - models: Словарь с обученными моделями (например, {'nn': nn_model, 'rf': rf_model, 'gb': gb_model}).
    - tokenizer: Токенизатор для текста.
    - bert_model: Модель BERT для извлечения текстовых эмбеддингов.
    - preprocess: Трансформации для изображений.
    - image_model: Модель для извлечения эмбеддингов изображений.
    - num_queries: Количество случайных запросов для тестирования.
    """
    # Выбор случайных запросов
    random_queries = test_queries.sample(n=num_queries, random_state=42)
    
    # Получение списка тестовых изображений
    test_images_paths = list(Path(test_images_folder).glob('*.jpg'))
    
    # Функция для извлечения текстовых эмбеддингов
    def extract_text_features(text, tokenizer, bert_model):
        inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True, max_length=128)
        with torch.no_grad():
            outputs = bert_model(**inputs)
            features = outputs.last_hidden_state[:, 0, :].squeeze().numpy()
        return features
    
    # Функция для извлечения эмбеддингов изображений
    def extract_image_features(image_path, image_model, preprocess):
        image = Image.open(image_path).convert('RGB')
        tensor = preprocess(image).unsqueeze(0).to(device)  # Перемещение на устройство
        with torch.no_grad():
            features = image_model(tensor).flatten().cpu().numpy()  # Перемещение обратно на CPU
        return features
    
    # Функция для поиска наиболее релевантного изображения
    def find_best_match(text, images, model, tokenizer, bert_model, preprocess, image_model):
        text_features = extract_text_features(text, tokenizer, bert_model)
        best_score = -1
        best_image = None
    
        for image_path in images:
            image_features = extract_image_features(image_path, image_model, preprocess)
            combined_features = np.concatenate([image_features, text_features]).reshape(1, -1)
        
            # Проверка типа модели
            if isinstance(model, torch.nn.Module):  # Если это нейронная сеть
                combined_features_tensor = torch.tensor(combined_features, dtype=torch.float32).to(device)
                with torch.no_grad():
                    score = model(combined_features_tensor).item()  # Прямой проход через модель
            else:  # Если это модель scikit-learn
                score = model.predict(combined_features)[0]
        
            if score > best_score:
                best_score = score
                best_image = image_path
    
        return best_image, best_score
    
    # Тестирование для каждого запроса
    results = []
    for idx, row in random_queries.iterrows():
        query_text = row['query_text']
        print(f"\nЗапрос: {query_text}")
        
        # Поиск наиболее релевантного изображения для каждой модели
        for model_name, model in models.items():
            best_image, score = find_best_match(
                query_text, test_images_paths, model, tokenizer, bert_model, preprocess, image_model
            )
            print(f"Модель: {model_name}, Наиболее релевантное изображение: {best_image}, Оценка: {score:.4f}")
            
            # Визуализация результата
            plt.figure(figsize=(8, 4))
            plt.title(f"Запрос: {query_text}\nМодель: {model_name}, Оценка: {score:.4f}")
            img = Image.open(best_image)
            plt.imshow(img)
            plt.axis('off')
            plt.show()
            
            # Сохранение результата
            results.append({
                'query_text': query_text,
                'model': model_name,
                'best_image': best_image,
                'score': score
            })
    
    # Возврат результатов
    return pd.DataFrame(results)

# %% [markdown]
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/8/81/Stop_sign.png/240px-Stop_sign.png" align=left width=35, heigth=35>
# <div class="alert alert-danger">
#
# Код этой функции никак не связан с предыдущим проектом
#
#  - использован совершенно другой подход к получению эмбеддинга текста (для обучения мы снимали эмбеддинг с нулевого CLS токена, а здесь ты используешь pooler_output
#
#
#  - использованный подход к классификации отличается от о того, к которому мы шли весь проект (создавали признаки и целевую метку, обучали модель определять соответствие)
#
# Здесь ты просто берешь какой-то необученный слой (считай рандомную матрицу), которая будет пересоздаваться при каждом вызове функции.
#
# Для определения, соответствует ли изображение описанию пожалуйста используй модель, которую мы обучали на прошлом этапе.
#
#
# </div>

# %% [markdown]
# <div class="alert" style="background-color:#ead7f7;color:#8737bf">
# Мой косяк, сегодня думал исправить, да ревью раньше прилетело.
# </div>

# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Идеи и альтернативные подходы</b>
#   Если хочешь получить хорошо работающее решение без обучения, то можешь провести эксперимент с нейронной сетью CLIP от OPEN AI (это не обязательно, только если хочешь добиться хороших результатов в этом проекте).
#
#   Про эту нейронку много где написано, но можешь посмотреть например вот здесь  https://habr.com/ru/post/539312/.
#
#   А для написания  реализации наиболее удобной лично для меня оказалась библиотека sbert. https://www.sbert.net/examples/applications/image-search/README.html
#
#
# <hr>
#
# Также неплохо работает следующий подход без предобученных моделей (к тому же легко реализуемый).
#
#
# Вместо того, чтобы подавать на вход модели изображение + текст и получать меру соответствия, поступаем по другому.
#
# На вход модели подаем вектор описания, а на выходе учимся предсказывать вектор изображения.
#
# По поводу метрик тут ситуация следующая. Точно работает следующий подход
#
#   - берем метрику mse, но тогда нужно чтобы модель её уменьшала. А значит в обучении используем только пары заведомо сответствующие друг другу
#
# Похоже что ты пытался использовать похожий подход. Но ключевое отличие - нужно обучить нейронку, которая будет по описанию предсказыать изображение, а не пытаться использовать просто необученный слой.
#
#
# </div>

# %%
ml_models = {
    'Gradient Boosting': gb_model,
    'Neural Network': nn_model
}

# %%
# Вызов функции тестирования
results_df = test_model(test_queries, test_img_folder, ml_models, tokenizer, bert_model, preprocess, resnet)

# Вывод результатов
print("\nРезультаты тестирования:")
display(results_df)
# Out:
# Запрос: A group of girls who are gothically dressed standing together
# Модель: Gradient Boosting, Наиболее релевантное изображение: to_upload\test_images\3517023411_a8fbd15230.jpg, Оценка: 0.2145
# Модель: Neural Network, Наиболее релевантное изображение: to_upload\test_images\3356748019_2251399314.jpg, Оценка: 0.1597
# Запрос: A woman and girl riding downhill on a sled with a dog running alongside them
# Модель: Gradient Boosting, Наиболее релевантное изображение: to_upload\test_images\3393035454_2d2370ffd4.jpg, Оценка: 0.1034
# Модель: Neural Network, Наиболее релевантное изображение: to_upload\test_images\3517023411_a8fbd15230.jpg, Оценка: 0.1395
# Запрос: The dog is running .
# Модель: Gradient Boosting, Наиболее релевантное изображение: to_upload\test_images\3044359043_627488ddf0.jpg, Оценка: 0.1799
# Модель: Neural Network, Наиболее релевантное изображение: to_upload\test_images\1319634306_816f21677f.jpg, Оценка: 0.2211
# ...

# %% [markdown]
# #### Итог:
# 1. **Обработка тестовых изображений**:
#    - Все тестовые изображения успешно обработаны, и их векторы сохранены в `test_img_vectors`.
#
# 2. **Выбор запросов**:
#    - Из файла `test_queries.csv` выбраны 10 случайных запросов для тестирования.
#
# 3. **Поиск релевантных изображений**:
#    - Для каждого запроса найдено наиболее релевантное изображение на основе косинусного сходства. Однако значения сходства оказались относительно низкими (в диапазоне от 0.0163 до 0.1087), что указывает на возможные трудности модели в точном сопоставлении текстовых запросов и изображений.
#
# 4. **Визуализация результатов**:
#    - Для каждого запроса отображены текст запроса и наиболее релевантное изображение. Это позволяет визуально оценить качество поиска и убедиться, насколько найденные изображения соответствуют запросам.
#
# #### Выводы:
# - Neural Network в целом лучше справляется с задачами, требующими понимания контекста, динамики и сложных сцен.
# - Gradient Boosting может быть полезен для более простых задач, но его результаты могут быть менее точными для сложных запросов.

# %% [markdown]
# ## 8. Выводы
#
# - [x] Jupyter Notebook открыт
# - [x] Весь код выполняется без ошибок
# - [x] Ячейки с кодом расположены в порядке исполнения
# - [x] Исследовательский анализ данных выполнен
# - [x] Проверены экспертные оценки и краудсорсинговые оценки
# - [x] Из датасета исключены те объекты, которые выходят за рамки юридических ограничений
# - [x] Изображения векторизованы
# - [x] Текстовые запросы векторизованы
# - [x] Данные корректно разбиты на тренировочную и тестовую выборки
# - [x] Предложена метрика качества работы модели
# - [x] Предложена модель схожести изображений и текстового запроса
# - [x] Модель обучена
# - [x] По итогам обучения модели сделаны выводы
# - [x] Проведено тестирование работы модели
# - [x] По итогам тестирования визуально сравнили качество поиска

# %% [markdown]
# <img src="http://s3.amazonaws.com/pix.iemoji.com/images/emoji/apple/ios-12/256/waving-hand.png" align=left width=44, heigth=44>
# <div class="alert alert-info">
# <b> Заключительный комментарий</b>
#
# Подведем итоги. Я вижу, что в целом с проектом ты справляешься.
#
# Проведено исследование и предобработка данных. Выполнена векторизация изображений и текстовых описаний. Обучены модели для предсказания степени соответствия.
#
#
# Пожалуйста отработай все красные комментарии.
#
# Желтые комментарии на твое усмотрение. Но учитывая что наш подход "не взлетел" и нужно хоть что-то показать заказчику, попробуй показать возможный инференс с помщью CLIP. С библиотекой sentence-transformers это делается буквально в 10 строк.
# Жду твою работу на повторное ревью.
# </div>
